# %%
import pandas as pd
from pathlib import Path

def import_data(filename):
    # ".." = remonter d'un niveau
    data_path = Path("..") / "Data" / filename
    return pd.read_csv(data_path, header=1)

def import_geojson(filename):
    data_path = Path("..") /Path("Data") / filename
    return gpd.read_file(data_path)

def rename_and_transpose(df):
    # 1. Renommer la première colonne
    df.columns.values[0] = "Year"
    
    # 2. Transposer
    df_t = df.transpose()
    
    # 3. Mettre la première ligne comme en-tête
    df_t.columns = df_t.iloc[0]     # La première ligne devient l’en-tête
    df_t = df_t.drop(df_t.index[0]) # Supprimer cette ligne des données
    
    return df_t

def rename_and_transpose2(df):
    # 1. Renommer la première colonne
    df.columns.values[0] = "Year"
    
    # 2. Transposer
    df_t = df.transpose()
    
    # 3. Mettre la première ligne comme en-tête
    df_t.columns = df_t.iloc[0]     # La première ligne devient l’en-tête
    df_t = df_t.drop(df_t.index[0]) # Supprimer cette ligne des données
    
    return df_

# %%
# !git diff
# Out:
# diff --git a/Code/Git_Workflow.ipynb b/Code/Git_Workflow.ipynb
# index 93f85f1..3a6171a 100644
# --- a/Code/Git_Workflow.ipynb
# +++ b/Code/Git_Workflow.ipynb
# @@ -2,7 +2,7 @@
#   "cells": [
#    {
#     "cell_type": "code",
# -   "execution_count": 11,
# +   "execution_count": 23,
#     "id": "1e7bca38-738e-4ffa-b5f1-ae4753bbd722",
#     "metadata": {},
#     "outputs": [],
# @@ -21,13 +21,27 @@
#      "# Fonction add/commit/push\n",
#      "def git_add_commit_push(message=\"Mise Ã  jour du projet\"):\n",
#      "    subprocess.run([\"git\", \"add\", \".\"])\n",
# -    "    subprocess.run([\"git\", \"commit\", \"-m\", message])\n",
# -    "    subprocess.run([\"git\", \"push\", \"-u\", \"origin\", \"main\"])\n"
# +    "    subprocess.run([\"git\", \"commit\", \"-m\", message], check=True)\n",
# +    "    subprocess.run([\"git\", \"push\", \"-u\", \"origin\", \"main\"])\n",
# +    "\n",
# +    "def git_update_from_remote():\n",
# +    "    subprocess.run([\"git\", \"fetch\", \"origin\"])\n",
# +    "    subprocess.run([\"git\", \"reset\", \"--hard\", \"origin/main\"])\n"
#     ]
#    },
#    {
#     "cell_type": "code",
# -   "execution_count": null,
# +   "execution_count": 16,
# +   "id": "ca70f01b-c397-4d5d-9301-8cf6b48cb9f1",
# +   "metadata": {},
# +   "outputs": [],
# +   "source": [
# +    "git_update_from_remote()"
# +   ]
# +  },
# +  {
# +   "cell_type": "code",
# +   "execution_count": 14,
#     "id": "a8ced2de-3074-4b61-a5fd-7ba941f4e012",
#     "metadata": {},
#     "outputs": [],
# @@ -37,13 +51,56 @@
#    },
#    {
#     "cell_type": "code",
# -   "execution_count": 12,
# +   "execution_count": 24,
#     "id": "d3da717b-08f2-4a69-9e36-3a2aad1a94e2",
#     "metadata": {},
# -   "outputs": [],
# +   "outputs": [
# +    {
# +     "ename": "CalledProcessError",
# +     "evalue": "Command '['git', 'commit', '-m', 'Mise Ã  jour avec ..']' returned non-zero exit status 1.",
# +     "output_type": "error",
# +     "traceback": [
# +      "\u001b---------------------------------------------------------------------------\u001b",
# +      "\u001bCalledProcessError\u001b                        Traceback (most recent call last)",
# +      "\u001bCell\u001b\u001b \u001b\u001bIn[24]\u001b\u001b, line 1\u001b\n\u001b----> \u001b\u001b1\u001b \u001bgit_add_commit_push\u001b\u001b(\u001b\u001b\"\u001b\u001bMise Ã  jour avec ..\u001b\u001b\"\u001b\u001b)\u001b  \u001b# pousser tes modifications\u001b\n",
# +      "\u001bCell\u001b\u001b \u001b\u001bIn[23]\u001b\u001b, line 15\u001b, in \u001bgit_add_commit_push\u001b\u001b(message)\u001b\n\u001b     13\u001b \u001bdef\u001b\u001b \u001b\u001bgit_add_commit_push\u001b(message=\u001b\"\u001b\u001bMise Ã  jour du projet\u001b\u001b\"\u001b):\n\u001b     14\u001b     subprocess.run([\u001b\"\u001b\u001bgit\u001b\u001b\"\u001b, \u001b\"\u001b\u001badd\u001b\u001b\"\u001b, \u001b\"\u001b\u001b.\u001b\u001b\"\u001b[39m])\n\u001b---> \u001b\u001b15\u001b     \u001bsubprocess\u001b\u001b.\u001b\u001brun\u001b\u001b(\u001b\u001b[\u001b\u001b\"\u001b\u001bgit\u001b\u001b\"\u001b\u001b,\u001b\u001b \u001b\u001b\"\u001b\u001bcommit\u001b\u001b\"\u001b\u001b,\u001b\u001b \u001b\u001b\"\u001b\u001b-m\u001b\u001b\"\u001b\u001b,\u001b\u001b \u001b\u001bmessage\u001b\u001b[43m]\u001b\u001b,\u001b\u001b \u001b\u001bcheck\u001b\u001b=\u001b\u001bTrue\u001b\u001b)\u001b\n\u001b     16\u001b     subprocess.run([\u001b\"\u001b\u001bgit\u001b\u001b\"\u001b, \u001b\"\u001b\u001bpush\u001b\u001b\"\u001b, \u001b\"\u001b\u001b-u\u001b\u001b\"\u001b, \u001b\"\u001b\u001borigin\u001b\u001b\"\u001b, \u001b\"\u001b\u001bmain\u001b\u001b\"\u001b[39m])\n",
# +      "\u001bFile \u001b\u001b~\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\subprocess.py:577\u001b, in \u001brun\u001b\u001b(input, capture_output, timeout, check, *popenargs, **kwargs)\u001b\n\u001b    575\u001b     retcode = process.poll()\n\u001b    576\u001b     \u001bif\u001b check \u001band\u001b retcode:\n\u001b--> \u001b\u001b577\u001b         \u001braise\u001b CalledProcessError(retcode, process.args,\n\u001b    578\u001b                                  output=stdout, stderr=stderr)\n\u001b    579\u001b \u001breturn\u001b CompletedProcess(process.args, retcode, stdout, stderr)\n",
# +      "\u001bCalledProcessError\u001b: Command '['git', 'commit', '-m', 'Mise Ã  jour avec ..']' returned non-zero exit status 1."
# +     ]
# +    }
# +   ],
# +   "source": [
# +    "git_add_commit_push(\"Mise Ã  jour avec ..\")  # pousser tes modifications\n"
# +   ]
# +  },
# +  {
# +   "cell_type": "code",
# +   "execution_count": 22,
# +   "id": "46f6d612-ae4c-4c61-853a-71b57917c287",
# +   "metadata": {},
# +   "outputs": [
# +    {
# +     "name": "stdout",
# +     "output_type": "stream",
# +     "text": [
# +      "On branch main\n",
# +      "Your branch is up to date with 'origin/main'.\n",
# +      "\n",
# +      "nothing to commit, working tree clean\n"
# +     ]
# +    }
# +   ],
#     "source": [
# -    "git_add_commit_push(\"Mise Ã  jour avec git_Workflow\")  # pousser tes modifications\n"
# +    "!git status"
#     ]
# +  },
# +  {
# +   "cell_type": "code",
# +   "execution_count": null,
# +   "id": "e3499439-e154-4195-9b55-552e95d5cd3e",
# +   "metadata": {},
# +   "outputs": [],
# +   "source": []
#    }
#   ],
#   "metadata": {
# @@ -62,7 +119,7 @@
#     "name": "python",
#     "nbconvert_exporter": "python",
#     "pygments_lexer": "ipython3",
# -   "version": "3.14.0"
# +   "version": "3.13.7"
#    }
#   },
#   "nbformat": 4,
# diff --git a/Code/main.ipynb b/Code/main.ipynb
# index f944de5..e75ff93 100644
# --- a/Code/main.ipynb
# +++ b/Code/main.ipynb
# @@ -2,7 +2,7 @@
#   "cells": [
#    {
#     "cell_type": "code",
# -   "execution_count": 108,
# +   "execution_count": 4,
#     "id": "cf5c6cc7-7ac2-4c9c-bc57-533071ce8655",
#     "metadata": {},
#     "outputs": [],
# @@ -11,19 +11,14 @@
#      "from pathlib import Path\n",
#      "\n",
#      "def import_data(filename):\n",
# -    "    data_path = Path(\"Data\") / filename\n",
# +    "    # \"..\" = remonter d'un niveau\n",
# +    "    data_path = Path(\"..\") / \"Data\" / filename\n",
#      "    return pd.read_csv(data_path, header=1)\n",
#      "\n",
# -    "import geopandas as gpd\n",
# -    "from pathlib import Path\n",
# -    "\n",
#      "def import_geojson(filename):\n",
# -    "    data_path = Path(\"Data\") / filename\n",
# +    "    data_path = Path(\"..\") /Path(\"Data\") / filename\n",
#      "    return gpd.read_file(data_path)\n",
#      "\n",
# -    "import geopandas as gpd\n",
# -    "import matplotlib.pyplot as plt\n",
# -    "\n",
#      "def rename_and_transpose(df):\n",
#      "    # 1. Renommer la premiÃ¨re colonne\n",
#      "    df.columns.values[0] = \"Year\"\n",
# @@ -41,7 +36,208 @@
#    },
#    {
#     "cell_type": "code",
# -   "execution_count": 80,
# +   "execution_count": 6,
# +   "id": "e7b030c7-e800-491e-932e-540381c29388",
# +   "metadata": {},
# +   "outputs": [
# +    {
# +     "name": "stdout",
# +     "output_type": "stream",
# +     "text": [
# +      "diff --git a/Code/Git_Workflow.ipynb b/Code/Git_Workflow.ipynb\n",
# +      "index 93f85f1..3a6171a 100644\n",
# +      "--- a/Code/Git_Workflow.ipynb\n",
# +      "+++ b/Code/Git_Workflow.ipynb\n",
# +      "@@ -2,7 +2,7 @@\n",
# +      "  \"cells\": [\n",
# +      "   {\n",
# +      "    \"cell_type\": \"code\",\n",
# +      "-   \"execution_count\": 11,\n",
# +      "+   \"execution_count\": 23,\n",
# +      "    \"id\": \"1e7bca38-738e-4ffa-b5f1-ae4753bbd722\",\n",
# +      "    \"metadata\": {},\n",
# +      "    \"outputs\": [],\n",
# +      "@@ -21,13 +21,27 @@\n",
# +      "     \"# Fonction add/commit/push\\n\",\n",
# +      "     \"def git_add_commit_push(message=\\\"Mise ÃƒÂ  jour du projet\\\"):\\n\",\n",
# +      "     \"    subprocess.run([\\\"git\\\", \\\"add\\\", \\\".\\\"])\\n\",\n",
# +      "-    \"    subprocess.run([\\\"git\\\", \\\"commit\\\", \\\"-m\\\", message])\\n\",\n",
# +      "-    \"    subprocess.run([\\\"git\\\", \\\"push\\\", \\\"-u\\\", \\\"origin\\\", \\\"main\\\"])\\n\"\n",
# +      "+    \"    subprocess.run([\\\"git\\\", \\\"commit\\\", \\\"-m\\\", message], check=True)\\n\",\n",
# +      "+    \"    subprocess.run([\\\"git\\\", \\\"push\\\", \\\"-u\\\", \\\"origin\\\", \\\"main\\\"])\\n\",\n",
# +      "+    \"\\n\",\n",
# +      "+    \"def git_update_from_remote():\\n\",\n",
# +      "+    \"    subprocess.run([\\\"git\\\", \\\"fetch\\\", \\\"origin\\\"])\\n\",\n",
# +      "+    \"    subprocess.run([\\\"git\\\", \\\"reset\\\", \\\"--hard\\\", \\\"origin/main\\\"])\\n\"\n",
# +      "    ]\n",
# +      "   },\n",
# +      "   {\n",
# +      "    \"cell_type\": \"code\",\n",
# +      "-   \"execution_count\": null,\n",
# +      "+   \"execution_count\": 16,\n",
# +      "+   \"id\": \"ca70f01b-c397-4d5d-9301-8cf6b48cb9f1\",\n",
# +      "+   \"metadata\": {},\n",
# +      "+   \"outputs\": [],\n",
# +      "+   \"source\": [\n",
# +      "+    \"git_update_from_remote()\"\n",
# +      "+   ]\n",
# +      "+  },\n",
# +      "+  {\n",
# +      "+   \"cell_type\": \"code\",\n",
# +      "+   \"execution_count\": 14,\n",
# +      "    \"id\": \"a8ced2de-3074-4b61-a5fd-7ba941f4e012\",\n",
# +      "    \"metadata\": {},\n",
# +      "    \"outputs\": [],\n",
# +      "@@ -37,13 +51,56 @@\n",
# +      "   },\n",
# +      "   {\n",
# +      "    \"cell_type\": \"code\",\n",
# +      "-   \"execution_count\": 12,\n",
# +      "+   \"execution_count\": 24,\n",
# +      "    \"id\": \"d3da717b-08f2-4a69-9e36-3a2aad1a94e2\",\n",
# +      "    \"metadata\": {},\n",
# +      "-   \"outputs\": [],\n",
# +      "+   \"outputs\": [\n",
# +      "+    {\n",
# +      "+     \"ename\": \"CalledProcessError\",\n",
# +      "+     \"evalue\": \"Command '['git', 'commit', '-m', 'Mise ÃƒÂ  jour avec ..']' returned non-zero exit status 1.\",\n",
# +      "+     \"output_type\": \"error\",\n",
# +      "+     \"traceback\": [\n",
# +      "+      \"\\u001b---------------------------------------------------------------------------\\u001b\",\n",
# +      "+      \"\\u001bCalledProcessError\\u001b                        Traceback (most recent call last)\",\n",
# +      "+      \"\\u001bCell\\u001b\\u001b \\u001b\\u001bIn[24]\\u001b\\u001b, line 1\\u001b\\n\\u001b----> \\u001b\\u001b1\\u001b \\u001bgit_add_commit_push\\u001b\\u001b(\\u001b\\u001b\\\"\\u001b\\u001bMise ÃƒÂ  jour avec ..\\u001b\\u001b\\\"\\u001b\\u001b)\\u001b  \\u001b# pousser tes modifications\\u001b\\n\",\n",
# +      "+      \"\\u001bCell\\u001b\\u001b \\u001b\\u001bIn[23]\\u001b\\u001b, line 15\\u001b, in \\u001bgit_add_commit_push\\u001b\\u001b(message)\\u001b\\n\\u001b     13\\u001b \\u001bdef\\u001b\\u001b \\u001b\\u001bgit_add_commit_push\\u001b(message=\\u001b\\\"\\u001b\\u001bMise ÃƒÂ  jour du projet\\u001b\\u001b\\\"\\u001b):\\n\\u001b     14\\u001b     subprocess.run([\\u001b\\\"\\u001b\\u001bgit\\u001b\\u001b\\\"\\u001b, \\u001b\\\"\\u001b\\u001badd\\u001b\\u001b\\\"\\u001b, \\u001b\\\"\\u001b\\u001b.\\u001b\\u001b\\\"\\u001b[39m])\\n\\u001b---> \\u001b\\u001b15\\u001b     \\u001bsubprocess\\u001b\\u001b.\\u001b\\u001brun\\u001b\\u001b(\\u001b\\u001b[\\u001b\\u001b\\\"\\u001b\\u001bgit\\u001b\\u001b\\\"\\u001b\\u001b,\\u001b\\u001b \\u001b\\u001b\\\"\\u001b\\u001bcommit\\u001b\\u001b\\\"\\u001b\\u001b,\\u001b\\u001b \\u001b\\u001b\\\"\\u001b\\u001b-m\\u001b\\u001b\\\"\\u001b\\u001b,\\u001b\\u001b \\u001b\\u001bmessage\\u001b\\u001b[43m]\\u001b\\u001b,\\u001b\\u001b \\u001b\\u001bcheck\\u001b\\u001b=\\u001b\\u001bTrue\\u001b\\u001b)\\u001b\\n\\u001b     16\\u001b     subprocess.run([\\u001b\\\"\\u001b\\u001bgit\\u001b\\u001b\\\"\\u001b, \\u001b\\\"\\u001b\\u001bpush\\u001b\\u001b\\\"\\u001b, \\u001b\\\"\\u001b\\u001b-u\\u001b\\u001b\\\"\\u001b, \\u001b\\\"\\u001b\\u001borigin\\u001b\\u001b\\\"\\u001b, \\u001b\\\"\\u001b\\u001bmain\\u001b\\u001b\\\"\\u001b[39m])\\n\",\n",
# +      "+      \"\\u001bFile \\u001b\\u001b~\\\\AppData\\\\Local\\\\Programs\\\\Python\\\\Python313\\\\Lib\\\\subprocess.py:577\\u001b, in \\u001brun\\u001b\\u001b(input, capture_output, timeout, check, *popenargs, **kwargs)\\u001b\\n\\u001b    575\\u001b     retcode = process.poll()\\n\\u001b    576\\u001b     \\u001bif\\u001b check \\u001band\\u001b retcode:\\n\\u001b--> \\u001b\\u001b577\\u001b         \\u001braise\\u001b CalledProcessError(retcode, process.args,\\n\\u001b    578\\u001b                                  output=stdout, stderr=stderr)\\n\\u001b    579\\u001b \\u001breturn\\u001b CompletedProcess(process.args, retcode, stdout, stderr)\\n\",\n",
# +      "+      \"\\u001bCalledProcessError\\u001b: Command '['git', 'commit', '-m', 'Mise ÃƒÂ  jour avec ..']' returned non-zero exit status 1.\"\n",
# +      "+     ]\n",
# +      "+    }\n",
# +      "+   ],\n",
# +      "+   \"source\": [\n",
# +      "+    \"git_add_commit_push(\\\"Mise ÃƒÂ  jour avec ..\\\")  # pousser tes modifications\\n\"\n",
# +      "+   ]\n",
# +      "+  },\n",
# +      "+  {\n",
# +      "+   \"cell_type\": \"code\",\n",
# +      "+   \"execution_count\": 22,\n",
# +      "+   \"id\": \"46f6d612-ae4c-4c61-853a-71b57917c287\",\n",
# +      "+   \"metadata\": {},\n",
# +      "+   \"outputs\": [\n",
# +      "+    {\n",
# +      "+     \"name\": \"stdout\",\n",
# +      "+     \"output_type\": \"stream\",\n",
# +      "+     \"text\": [\n",
# +      "+      \"On branch main\\n\",\n",
# +      "+      \"Your branch is up to date with 'origin/main'.\\n\",\n",
# +      "+      \"\\n\",\n",
# +      "+      \"nothing to commit, working tree clean\\n\"\n",
# +      "+     ]\n",
# +      "+    }\n",
# +      "+   ],\n",
# +      "    \"source\": [\n",
# +      "-    \"git_add_commit_push(\\\"Mise ÃƒÂ  jour avec git_Workflow\\\")  # pousser tes modifications\\n\"\n",
# +      "+    \"!git status\"\n",
# +      "    ]\n",
# +      "+  },\n",
# +      "+  {\n",
# +      "+   \"cell_type\": \"code\",\n",
# +      "+   \"execution_count\": null,\n",
# +      "+   \"id\": \"e3499439-e154-4195-9b55-552e95d5cd3e\",\n",
# +      "+   \"metadata\": {},\n",
# +      "+   \"outputs\": [],\n",
# +      "+   \"source\": []\n",
# +      "   }\n",
# +      "  ],\n",
# +      "  \"metadata\": {\n",
# +      "@@ -62,7 +119,7 @@\n",
# +      "    \"name\": \"python\",\n",
# +      "    \"nbconvert_exporter\": \"python\",\n",
# +      "    \"pygments_lexer\": \"ipython3\",\n",
# +      "-   \"version\": \"3.14.0\"\n",
# +      "+   \"version\": \"3.13.7\"\n",
# +      "   }\n",
# +      "  },\n",
# +      "  \"nbformat\": 4,\n",
# +      "diff --git a/Code/main.ipynb b/Code/main.ipynb\n",
# +      "index f944de5..2e1db34 100644\n",
# +      "--- a/Code/main.ipynb\n",
# +      "+++ b/Code/main.ipynb\n",
# +      "@@ -2,7 +2,7 @@\n",
# +      "  \"cells\": [\n",
# +      "   {\n",
# +      "    \"cell_type\": \"code\",\n",
# +      "-   \"execution_count\": 108,\n",
# +      "+   \"execution_count\": 4,\n",
# +      "    \"id\": \"cf5c6cc7-7ac2-4c9c-bc57-533071ce8655\",\n",
# +      "    \"metadata\": {},\n",
# +      "    \"outputs\": [],\n",
# +      "@@ -11,19 +11,14 @@\n",
# +      "     \"from pathlib import Path\\n\",\n",
# +      "     \"\\n\",\n",
# +      "     \"def import_data(filename):\\n\",\n",
# +      "-    \"    data_path = Path(\\\"Data\\\") / filename\\n\",\n",
# +      "+    \"    # \\\"..\\\" = remonter d'un niveau\\n\",\n",
# +      "+    \"    data_path = Path(\\\"..\\\") / \\\"Data\\\" / filename\\n\",\n",
# +      "     \"    return pd.read_csv(data_path, header=1)\\n\",\n",
# +      "     \"\\n\",\n",
# +      "-    \"import geopandas as gpd\\n\",\n",
# +      "-    \"from pathlib import Path\\n\",\n",
# +      "-    \"\\n\",\n",
# +      "     \"def import_geojson(filename):\\n\",\n",
# +      "-    \"    data_path = Path(\\\"Data\\\") / filename\\n\",\n",
# +      "+    \"    data_path = Path(\\\"..\\\") /Path(\\\"Data\\\") / filename\\n\",\n",
# +      "     \"    return gpd.read_file(data_path)\\n\",\n",
# +      "     \"\\n\",\n",
# +      "-    \"import geopandas as gpd\\n\",\n",
# +      "-    \"import matplotlib.pyplot as plt\\n\",\n",
# +      "-    \"\\n\",\n",
# +      "     \"def rename_and_transpose(df):\\n\",\n",
# +      "     \"    # 1. Renommer la premiÃƒÂ¨re colonne\\n\",\n",
# +      "     \"    df.columns.values[0] = \\\"Year\\\"\\n\",\n",
# +      "@@ -41,7 +36,7 @@\n",
# +      "   },\n",
# +      "   {\n",
# +      "    \"cell_type\": \"code\",\n",
# +      "-   \"execution_count\": 80,\n",
# +      "+   \"execution_count\": 2,\n",
# +      "    \"id\": \"3e3c8982-a3cf-4f8d-bdfd-867dad799ec7\",\n",
# +      "    \"metadata\": {},\n",
# +      "    \"outputs\": [],\n",
# +      "@@ -114,7 +109,7 @@\n",
# +      "   },\n",
# +      "   {\n",
# +      "    \"cell_type\": \"code\",\n",
# +      "-   \"execution_count\": 112,\n",
# +      "+   \"execution_count\": 5,\n",
# +      "    \"id\": \"3c9427ac-fb18-4495-b9fd-37622e36dd6e\",\n",
# +      "    \"metadata\": {},\n",
# +      "    \"outputs\": [\n",
# +      "@@ -320,7 +315,7 @@\n",
# +      "        \"[5 rows x 64 columns]\"\n",
# +      "       ]\n",
# +      "      },\n",
# +      "-     \"execution_count\": 112,\n",
# +      "+     \"execution_count\": 5,\n",
# +      "      \"metadata\": {},\n",
# +      "      \"output_type\": \"execute_result\"\n",
# +      "     }\n"
# +     ]
# +    },
# +    {
# +     "name": "stderr",
# +     "output_type": "stream",
# +     "text": [
# +      "warning: in the working copy of 'Code/Git_Workflow.ipynb', LF will be replaced by CRLF the next time Git touches it\n",
# +      "warning: in the working copy of 'Code/main.ipynb', LF will be replaced by CRLF the next time Git touches it\n"
# +     ]
# +    }
# +   ],
# +   "source": [
# +    "!git diff"
# +   ]
# +  },
# +  {
# +   "cell_type": "code",
# +   "execution_count": 2,
#     "id": "3e3c8982-a3cf-4f8d-bdfd-867dad799ec7",
#     "metadata": {},
#     "outputs": [],
# @@ -114,7 +310,7 @@
#    },
#    {
#     "cell_type": "code",
# -   "execution_count": 112,
# +   "execution_count": 5,
#     "id": "3c9427ac-fb18-4495-b9fd-37622e36dd6e",
#     "metadata": {},
#     "outputs": [
# @@ -320,7 +516,7 @@
#         "[5 rows x 64 columns]"
#        ]
#       },
# -     "execution_count": 112,
# +     "execution_count": 5,
#       "metadata": {},
#       "output_type": "execute_result"
#      }
# warning: in the working copy of 'Code/Git_Workflow.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Code/main.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import TwoSlopeNorm, LinearSegmentedColormap
import matplotlib.cm as cm
import pandas as pd

def plot_world_map(df, gdf, year, country_col="NAME"):
    """
    Carte du monde pour une année donnée.
    Bleu → négatif, Blanc → 0, Rouge → positif
    Pays sans données en gris clair avec patch centré sous la colorbar.
    """
    year = str(year)

    # Préparer les données
    df_year = df[[year]].copy()
    df_year = df_year.reset_index().rename(columns={"index": country_col, year: "value"})
    df_year["value"] = pd.to_numeric(df_year["value"], errors='coerce')

    # Fusion avec le GeoDataFrame
    gdf_merged = gdf.merge(df_year, on=country_col, how="left")

    # Création de la figure
    fig, ax = plt.subplots(figsize=(14, 7))

    # Colormap bleu → blanc → rouge
    colors = [(0, 0, 0.8), (1, 1, 1), (0.8, 0, 0)]
    cmap = LinearSegmentedColormap.from_list("blue_white_red", colors, N=256)

    # Normalisation avec blanc à 0
    vmin = gdf_merged["value"].min()
    vmax = gdf_merged["value"].max()
    norm = TwoSlopeNorm(vmin=vmin, vcenter=0, vmax=vmax)

    # Tracer la carte
    gdf_merged.plot(column="value",
                    cmap=cmap,
                    norm=norm,
                    linewidth=0.5,
                    edgecolor="black",
                    missing_kwds={"color": "lightgrey"},
                    ax=ax)

    # Colorbar simple
    sm = cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, orientation="vertical",
                        fraction=0.025, pad=0.02)
    cbar.set_label("TgC/year", fontsize=12)

    # Patch gris "Sans données"
    patch = mpatches.Patch(color="lightgrey", label="Sans données")
    cbar.ax.legend(handles=[patch],
                   loc='upper center',
                   bbox_to_anchor=(0.5, -0.1),
                   frameon=False,
                   fontsize=10)

    # Titre
    ax.set_title(f"Net Emission in {year}", fontsize=16, pad=15)
    ax.axis("off")

    plt.show(block=True)

# %%
df = import_data("GCB_NetEmissions_Countries.csv")
df_t = rename_and_transpose(df)

# Garder seulement les colonnes dont le nom est convertible en entier (les années)
df_t = df_t[[c for c in df_t.columns if str(c).replace('.0','').isdigit()]]

# Convertir les colonnes en int
df_t.columns = [int(str(c).replace('.0','')) for c in df_t.columns]


df_t.head()
# Out:
#                 1960      1961      1962      1963     1964     1965     1966  \
# Afghanistan  4.17891   3.59662   3.32416   3.23023  2.79609  2.84472  2.62185
# Albania      0.98295    0.7255   0.60905   0.46588  0.65877  0.70381    0.716
# Algeria      4.38642    1.8356    0.8065    0.2254  0.33382  0.09481  0.57291
# Andorra      0.00563    0.0074   0.00565   0.00443  0.00364  0.00305  0.00272
# Angola       25.0768  17.26244  12.35364  10.40859  8.94263   8.1837   7.5842
#
#                 1967     1968     1969  ...      2014      2015      2016  \
# Afghanistan  2.30549  2.17469  2.01775  ...    0.2982   0.28716   0.35204
# Albania      0.60361  0.58366  0.57642  ...   0.05507   0.17305   0.03659
# Algeria     -0.02041  -0.1056   0.0305  ...  -0.00398    0.0206   0.06336
# Andorra      0.00202  0.00252  0.00178  ...  -0.00144  -0.00155  -0.00155
# Angola       7.22189  7.20413  6.35542  ...  29.27385  30.00732  27.66582
#
#                  2017      2018      2019      2020      2021      2022  \
# Afghanistan   1.02206   0.69029   1.35329     0.983   1.33826    1.5648
# Albania       0.04546  -0.01066  -0.04848  -0.09121   -0.1042  -0.13681
# Algeria       0.07388   0.29755   0.14063   0.16296   0.20926    0.2678
# Andorra      -0.00158  -0.00188  -0.00201  -0.00203  -0.00197  -0.00198
# Angola       26.76205  25.13832  24.01049  23.17754  23.47849  23.32447
#
#                  2023
# Afghanistan   1.69074
# Albania      -0.17435
# Algeria        0.2807
# Andorra        -0.002
# Angola       23.35756
#
# [5 rows x 64 columns]

# %%
gdf = import_geojson("world-administrative-boundaries.geojson")
gdf.head()
# Out:
#                                         geo_point_2d  iso3        status  \
# 0  { "lon": -16.984917430414384, "lat": 32.747916...  None  PT Territory
# 1  { "lon": 33.743791080217562, "lat": 21.8927401...  None   Adm. by EGY
# 2  { "lon": 9.5613358449883421, "lat": 34.1108585...   TUN  Member State
# 3  { "lon": 43.77213543247138, "lat": 33.04802449...   IRQ  Member State
# 4  { "lon": -6.3178452255610269, "lat": 31.883624...   MAR  Member State
#
#   color_code             name continent           region  \
# 0        PRT  Madeira Islands    Europe  Southern Europe
# 1        EGY  Ma'tan al-Sarra    Africa  Northern Africa
# 2        TUN          Tunisia    Africa  Northern Africa
# 3        IRQ             Iraq      Asia     Western Asia
# 4        MAR          Morocco    Africa  Northern Africa
#
#   iso_3166_1_alpha_2_codes     french_short  \
# 0                     None  Madeira Islands
# 1                     None  Ma'tan al-Sarra
# 2                       TN          Tunisie
# 3                       IQ             Iraq
# 4                       MA            Maroc
#
#                                             geometry
# 0  POLYGON ((-17.1025 32.82333, -17.05306 32.8094...
# 1  POLYGON ((33.25104 21.99977, 34.15064 21.99603...
# 2  MULTIPOLYGON (((10.99361 33.75, 10.93778 33.72...
# 3  POLYGON ((44.78734 37.14971, 44.76617 37.11228...
# 4  POLYGON ((-2.94694 35.32916, -2.96618 35.31663...

# %%
# Tracé de la carte pour l’année choisie
plot_world_map(df_t, gdf, year=1990, country_col="name")
  # adapte le nom du champ pays si nécessaire

# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
import branca.colormap as bcm
import tempfile
import webbrowser

def plot_world_map_interactive(df, gdf, year=2020, country_col="NAME", title=None, unit="TgC/year"):
    """
    Create an interactive Folium map for a specific year showing net emissions per country.

    Parameters:
    - df : pd.DataFrame
        DataFrame with country emissions data. Must have a column with the year as int.
    - gdf : gpd.GeoDataFrame
        GeoDataFrame with geometries for countries.
    - year : int, default 2020
        Year of data to display.
    - country_col : str, default "NAME"
        Column in gdf containing country names.
    - title : str, optional
        Title of the map.
    - unit : str, default "TgC/year"
        Unit of the values displayed.
    """
    
    if title is None:
        title = f"Land Use Change - Net emission per country in {year}"

    # Prepare GeoDataFrame by merging data
    gdf_merged = gdf.copy()
    gdf_merged = gdf_merged.set_index(country_col)
    
    df_numeric = df[[year]].apply(pd.to_numeric, errors='coerce')
    gdf_merged[year] = df_numeric[year]

    # Colormap
    vmin = df_numeric.min().min()
    vmax = df_numeric.max().max()
    cmap = plt.get_cmap("bwr")
    norm = colors.TwoSlopeNorm(vmin=vmin, vcenter=0, vmax=vmax)

    # Create Folium map
    m = folium.Map(location=[20, 0], zoom_start=2, tiles="cartodbpositron")

    # Add countries
    for idx, row in gdf_merged.iterrows():
        val = row[year]
        color = "#D3D3D3" if pd.isna(val) else colors.to_hex(cmap(norm(val)))
        popup_text = f"<b>{idx}</b><br>{val:.2f} {unit}" if pd.notna(val) else f"<b>{idx}</b><br>No data"

        folium.GeoJson(
            row["geometry"],
            style_function=lambda feature, fill=color: {
                "fillColor": fill,
                "color": "black",
                "weight": 0.5,
                "fillOpacity": 0.7
            },
            tooltip=folium.Tooltip(popup_text, sticky=True)
        ).add_to(m)

    # Add color legend
    colormap = bcm.LinearColormap(colors=["blue", "white", "red"], vmin=vmin, vmax=vmax, caption=unit)
    colormap.add_to(m)

    # Add title
    m.get_root().html.add_child(
        folium.Element(f'<h3 align="center" style="font-size:20px"><b>{title} [{unit}]</b></h3>')
    )

    # Save and open in browser
    tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".html")
    m.save(tmp.name)
    webbrowser.open(f"file://{tmp.name}")

    return m

# %%
# Example usage:

# df: DataFrame with columns like ['Country', 2020, 2021, ...]
# gdf: GeoDataFrame with geometries and a column 'NAME' for country names

map_2020 = plot_world_map_interactive(
    df=df_t,            # your data DataFrame
    gdf=gdf,          # your GeoDataFrame
    year=2020,        # year to display
    country_col="name",  # column in gdf with country names
    title="Net Carbon Emissions 2020",  # optional title
    unit="TgC/year"       # optional unit
)

# %%
git clone https://github.com/aubinnormand/NetZero.git
# Out:
#   Cell In[1], line 1
#     git clone https://github.com/aubinnormand/NetZero.git
#         ^
# SyntaxError: invalid syntax
