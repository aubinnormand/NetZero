# %% [markdown]
# ## Importation des données

# %%
import sys
from pathlib import Path
import importlib
import ipynbname 
import pandas as pd
import geopandas as gpd
from datetime import datetime

code_path = ipynbname.path().parent.parent
# Ajouter le dossier scripts au path
scripts_path = code_path  / "scripts"
base_path=code_path.parent
sys.path.append(str(scripts_path.resolve()))

import data_utils  # importe le module une première fois

# Après avoir modifié data_utils.py
importlib.reload(data_utils)

# Maintenant tu peux accéder aux fonctions mises à jour
from data_utils import import_data_raw, import_data_sig, melt_long_format, clean_year_column, save_long_dataframe, concat_intermediate_files

# %%
#Country data
filename="data_final_all_norm.csv"
filepath= base_path/ "Data" / 'data_final' / filename

df_data = pd.read_csv(filepath)
df_data.head(100)
# Out:
#     Year      Country    Value      Unit             Indicator Source  \
# 0   1960  Afghanistan  4.17891  TgC/year  LULUCF Net emissions    GCB
# 1   1961  Afghanistan  3.59662  TgC/year  LULUCF Net emissions    GCB
# 2   1962  Afghanistan  3.32416  TgC/year  LULUCF Net emissions    GCB
# 3   1963  Afghanistan  3.23023  TgC/year  LULUCF Net emissions    GCB
# 4   1964  Afghanistan  2.79609  TgC/year  LULUCF Net emissions    GCB
# ..   ...          ...      ...       ...                   ...    ...
# 95  1991      Albania  0.07904  TgC/year  LULUCF Net emissions    GCB
# 96  1992      Albania  0.04298  TgC/year  LULUCF Net emissions    GCB
# 97  1993      Albania -0.06407  TgC/year  LULUCF Net emissions    GCB
# 98  1994      Albania -0.17971  TgC/year  LULUCF Net emissions    GCB
# 99  1995      Albania -0.17141  TgC/year  LULUCF Net emissions    GCB
#
#    Country_code      country  gdp_percapita_current_usd  \
# 0            AF  Afghanistan                        NaN
# 1            AF  Afghanistan                        NaN
# 2            AF  Afghanistan                        NaN
# 3            AF  Afghanistan                        NaN
# 4            AF  Afghanistan                        NaN
# ..          ...          ...                        ...
# 95           AL      Albania                 336.586995
# 96           AL      Albania                 200.852220
# 97           AL      Albania                 367.279225
# 98           AL      Albania                 586.416135
# 99           AL      Albania                 911.320465
#
#     gdp_percapita_ppp_current_intl  ... Value_norm_gdp         Unit_norm_gdp  \
# 0                              NaN  ...            NaN  TgC/year/billion USD
# 1                              NaN  ...            NaN  TgC/year/billion USD
# 2                              NaN  ...            NaN  TgC/year/billion USD
# 3                              NaN  ...            NaN  TgC/year/billion USD
# 4                              NaN  ...            NaN  TgC/year/billion USD
# ..                             ...  ...            ...                   ...
# 95                     1988.181406  ...       0.071883  TgC/year/billion USD
# 96                     1898.820304  ...       0.065903  TgC/year/billion USD
# 97                     2142.681185  ...      -0.054053  TgC/year/billion USD
# 98                     2384.728785  ...      -0.095542  TgC/year/billion USD
# 99                     2776.187606  ...      -0.059003  TgC/year/billion USD
#
#    Value_norm_ppp          Unit_norm_ppp Value_norm_gdp_hab  \
# 0             NaN  TgC/year/billion PPP$                NaN
# 1             NaN  TgC/year/billion PPP$                NaN
# 2             NaN  TgC/year/billion PPP$                NaN
# 3             NaN  TgC/year/billion PPP$                NaN
# 4             NaN  TgC/year/billion PPP$                NaN
# ..            ...                    ...                ...
# 95       0.012169  TgC/year/billion PPP$           0.234828
# 96       0.006971  TgC/year/billion PPP$           0.213988
# 97      -0.009265  TgC/year/billion PPP$          -0.174445
# 98      -0.023494  TgC/year/billion PPP$          -0.306455
# 99      -0.019369  TgC/year/billion PPP$          -0.188090
#
#             Unit_norm_gdp_hab  Value_norm_ppp_hab           Unit_norm_ppp_hab  \
# 0   TgC/year/thousand USD/hab                 NaN  TgC/year/thousand PPP$/hab
# 1   TgC/year/thousand USD/hab                 NaN  TgC/year/thousand PPP$/hab
# 2   TgC/year/thousand USD/hab                 NaN  TgC/year/thousand PPP$/hab
# 3   TgC/year/thousand USD/hab                 NaN  TgC/year/thousand PPP$/hab
# 4   TgC/year/thousand USD/hab                 NaN  TgC/year/thousand PPP$/hab
# ..                        ...                 ...                         ...
# 95  TgC/year/thousand USD/hab            0.039755  TgC/year/thousand PPP$/hab
# 96  TgC/year/thousand USD/hab            0.022635  TgC/year/thousand PPP$/hab
# 97  TgC/year/thousand USD/hab           -0.029902  TgC/year/thousand PPP$/hab
# 98  TgC/year/thousand USD/hab           -0.075359  TgC/year/thousand PPP$/hab
# 99  TgC/year/thousand USD/hab           -0.061743  TgC/year/thousand PPP$/hab
#
#     Value_norm_densite  Unit_norm_densite
# 0                  NaN   TgC/year/hab/km²
# 1             0.254591   TgC/year/hab/km²
# 2             0.230543   TgC/year/hab/km²
# 3             0.219361   TgC/year/hab/km²
# 4             0.185820   TgC/year/hab/km²
# ..                 ...                ...
# 95            0.000663   TgC/year/hab/km²
# 96            0.000363   TgC/year/hab/km²
# 97           -0.000544   TgC/year/hab/km²
# 98           -0.001535   TgC/year/hab/km²
# 99           -0.001473   TgC/year/hab/km²
#
# [100 rows x 34 columns]

# %%
df_data[df_data['Country_code']=='CN']
# Out:
#       Year Country      Value      Unit             Indicator Source  \
# 2240  1960   China   62.36105  TgC/year  LULUCF Net emissions    GCB
# 2241  1961   China  144.74457  TgC/year  LULUCF Net emissions    GCB
# 2242  1962   China  151.55702  TgC/year  LULUCF Net emissions    GCB
# 2243  1963   China  167.19472  TgC/year  LULUCF Net emissions    GCB
# 2244  1964   China  143.64389  TgC/year  LULUCF Net emissions    GCB
# ...    ...     ...        ...       ...                   ...    ...
# 2299  2019   China  -59.38876  TgC/year  LULUCF Net emissions    GCB
# 2300  2020   China  -58.86489  TgC/year  LULUCF Net emissions    GCB
# 2301  2021   China  -61.12004  TgC/year  LULUCF Net emissions    GCB
# 2302  2022   China  -63.09483  TgC/year  LULUCF Net emissions    GCB
# 2303  2023   China  -62.95872  TgC/year  LULUCF Net emissions    GCB
#
#      Country_code country  gdp_percapita_current_usd  \
# 2240           CN   China                  89.715075
# 2241           CN   China                  75.965501
# 2242           CN   China                  71.061685
# 2243           CN   China                  74.468154
# 2244           CN   China                  85.661107
# ...           ...     ...                        ...
# 2299           CN   China               10342.900952
# 2300           CN   China               10627.463799
# 2301           CN   China               12887.435724
# 2302           CN   China               12970.605641
# 2303           CN   China               12951.178240
#
#       gdp_percapita_ppp_current_intl  ... Value_norm_gdp  \
# 2240                             NaN  ...       1.042021
# 2241                             NaN  ...       2.885525
# 2242                             NaN  ...       3.203438
# 2243                             NaN  ...       3.290443
# 2244                             NaN  ...       2.401194
# ...                              ...  ...            ...
# 2299                    17600.890757  ...      -0.004079
# 2300                    18267.478346  ...      -0.003925
# 2301                    20843.297835  ...      -0.003358
# 2302                    23032.176627  ...      -0.003445
# 2303                    25179.119307  ...      -0.003446
#
#              Unit_norm_gdp Value_norm_ppp          Unit_norm_ppp  \
# 2240  TgC/year/billion USD            NaN  TgC/year/billion PPP$
# 2241  TgC/year/billion USD            NaN  TgC/year/billion PPP$
# 2242  TgC/year/billion USD            NaN  TgC/year/billion PPP$
# 2243  TgC/year/billion USD            NaN  TgC/year/billion PPP$
# 2244  TgC/year/billion USD            NaN  TgC/year/billion PPP$
# ...                    ...            ...                    ...
# 2299  TgC/year/billion USD      -0.002397  TgC/year/billion PPP$
# 2300  TgC/year/billion USD      -0.002284  TgC/year/billion PPP$
# 2301  TgC/year/billion USD      -0.002076  TgC/year/billion PPP$
# 2302  TgC/year/billion USD      -0.001940  TgC/year/billion PPP$
# 2303  TgC/year/billion USD      -0.001772  TgC/year/billion PPP$
#
#      Value_norm_gdp_hab          Unit_norm_gdp_hab  Value_norm_ppp_hab  \
# 2240         695.101131  TgC/year/thousand USD/hab                 NaN
# 2241        1905.398739  TgC/year/thousand USD/hab                 NaN
# 2242        2132.752986  TgC/year/thousand USD/hab                 NaN
# 2243        2245.184160  TgC/year/thousand USD/hab                 NaN
# 2244        1676.885745  TgC/year/thousand USD/hab                 NaN
# ...                 ...                        ...                 ...
# 2299          -5.741983  TgC/year/thousand USD/hab           -3.374191
# 2300          -5.538941  TgC/year/thousand USD/hab           -3.222387
# 2301          -4.742607  TgC/year/thousand USD/hab           -2.932359
# 2302          -4.864447  TgC/year/thousand USD/hab           -2.739421
# 2303          -4.861235  TgC/year/thousand USD/hab           -2.500434
#
#                Unit_norm_ppp_hab  Value_norm_densite  Unit_norm_densite
# 2240  TgC/year/thousand PPP$/hab                 NaN   TgC/year/hab/km²
# 2241  TgC/year/thousand PPP$/hab            2.057908   TgC/year/hab/km²
# 2242  TgC/year/thousand PPP$/hab            2.137157   TgC/year/hab/km²
# 2243  TgC/year/thousand PPP$/hab            2.300433   TgC/year/hab/km²
# 2244  TgC/year/thousand PPP$/hab            1.931059   TgC/year/hab/km²
# ...                          ...                 ...                ...
# 2299  TgC/year/thousand PPP$/hab           -0.396062   TgC/year/hab/km²
# 2300  TgC/year/thousand PPP$/hab           -0.391635   TgC/year/hab/km²
# 2301  TgC/year/thousand PPP$/hab           -0.406276   TgC/year/hab/km²
# 2302  TgC/year/thousand PPP$/hab           -0.419458   TgC/year/hab/km²
# 2303  TgC/year/thousand PPP$/hab           -0.418987   TgC/year/hab/km²
#
# [64 rows x 34 columns]

# %%
#Global sig
gdf_world=import_data_sig('world.geojson',base_path)


def simplify_geom(geom, tol=0.1):
    if geom is None:
        return None
    if geom.geom_type == 'Polygon':
        return geom.simplify(tol, preserve_topology=True)
    elif geom.geom_type == 'MultiPolygon':
        return type(geom)([poly.simplify(tol, preserve_topology=True) for poly in geom.geoms])
    return geom
    
gdf_world = gdf_world[gdf_world['Country_code'].notna()].copy()
gdf_world['geometry'] = gdf_world['geometry'].apply(lambda g: simplify_geom(g, tol=0.1))
gdf_world.head(10)
# Out:
#                                          geo_point_2d iso3        status  \
# 2   { "lon": 9.5613358449883421, "lat": 34.1108585...  TUN  Member State
# 3   { "lon": 43.77213543247138, "lat": 33.04802449...  IRQ  Member State
# 4   { "lon": -6.3178452255610269, "lat": 31.883624...  MAR  Member State
# 5   { "lon": 25.088778010977098, "lat": -28.993203...  ZAF  Member State
# 6   { "lon": -61.253176819842295, "lat": 10.468641...  TTO  Member State
# 7   { "lon": 2.5519552167777979, "lat": 46.5645020...  FRA  Member State
# 9   { "lon": 168.62692074653282, "lat": 7.64327257...  MHL  Member State
# 10  { "lon": 12.071742970356828, "lat": 42.7957823...  ITA  Member State
# 11  { "lon": -53.089819954013173, "lat": -10.77310...  BRA  Member State
# 12  { "lon": 29.871837767180068, "lat": -19.000098...  ZWE  Member State
#
#    color_code                 name continent           region Country_code  \
# 2         TUN              Tunisia    Africa  Northern Africa           TN
# 3         IRQ                 Iraq      Asia     Western Asia           IQ
# 4         MAR              Morocco    Africa  Northern Africa           MA
# 5         ZAF         South Africa    Africa  Southern Africa           ZA
# 6         TTO  Trinidad and Tobago  Americas        Caribbean           TT
# 7         FRA               France    Europe   Western Europe           FR
# 9         MHL     Marshall Islands   Oceania       Micronesia           MH
# 10        ITA                Italy    Europe  Southern Europe           IT
# 11        BRA               Brazil  Americas    South America           BR
# 12        ZWE             Zimbabwe    Africa   Eastern Africa           ZW
#
#          french_short              Country  \
# 2             Tunisie              Tunisia
# 3                Iraq                 Iraq
# 4               Maroc              Morocco
# 5      Afrique du Sud         South Africa
# 6   Trinité-et-Tobago  Trinidad and Tobago
# 7              France               France
# 9       Îles Marshall     Marshall Islands
# 10             Italie                Italy
# 11             Brésil               Brazil
# 12           Zimbabwe             Zimbabwe
#
#                                              geometry
# 2   MULTIPOLYGON (((10.96833 33.8575, 10.865 33.63...
# 3   POLYGON ((44.78734 37.14971, 44.85304 36.79458...
# 4   POLYGON ((-2.94694 35.32916, -2.87694 35.1418,...
# 5   POLYGON ((31.2975 -22.41476, 31.55083 -23.4766...
# 6   MULTIPOLYGON (((-60.92306 10.79722, -61.00445 ...
# 7   MULTIPOLYGON (((9.45958 42.98805, 9.55257 42.1...
# 9   MULTIPOLYGON (((168.13098 5.62236, 168.09497 5...
# 10  MULTIPOLYGON (((15.64794 38.26457, 15.0925 37....
# 11  MULTIPOLYGON (((-48.55056 -27.82139, -48.51778...
# 12  POLYGON ((30.41576 -15.63187, 30.42236 -16.005...

# %% [markdown]
# ## Visualisation des données

# %%
import plotly.graph_objects as go
import pandas as pd
import geopandas as gpd
import json
import webbrowser
from pathlib import Path

def plot_world_map_with_slider(df_data, gdf_world, indicator, output_html="map_slider", save=True,base_path='C:/Users/Aubin/Documents/NetZero'):
    """
    Carte du monde interactive avec un slider pour choisir l'année manuellement.
    Colorbar : vert <0, blanc =0, rouge >0.
    Si save=True, le fichier est sauvegardé dans NetZero/Résultats.
    """
    date_str = datetime.now().strftime("%Y%m%d")
    output_html=f"{output_html}_{date_str}.html"
    # Définir le dossier de sauvegarde : NetZero/Figures
    output_path = base_path/'Figures' / output_html

    # Filtrer pour l'indicateur choisi
    df_filtered = df_data[df_data['Value'] == indicator]
    
    # Fusionner avec le GeoDataFrame
    gdf_merged = gdf_world.merge(df_filtered, on='Country_code', how='left')
    
    # Conversion des géométries en GeoJSON
    #gdf_merged = gdf_merged.set_geometry('geometry')
    geojson_data = json.loads(gdf_merged.to_json())
    
    # Déterminer les bornes min et max pour la colorbar
    zmin = df_filtered['Value'].min()
    zmax = df_filtered['Value'].max()
    zmed = abs(zmin / (zmax - zmin)) if zmax != zmin else 0.5  # éviter division par zéro
    
    # Liste des années disponibles
    years = sorted(df_filtered['Year'].unique())
    
    # Création des traces, une par année
    traces = []
    for i, year in enumerate(years):
        df_year = gdf_merged[gdf_merged['Year'] == year]
        traces.append(
            go.Choropleth(
                geojson=geojson_data,
                locations=df_year.index,
                z=df_year['Value'],
                text=df_year['name'],
                colorscale=[[0, "green"], [zmed, "white"], [1, "red"]],
                zmin=zmin,
                zmax=zmax,
                zmid=0,  # blanc = 0
                colorbar_title=indicator,
                visible=(i==0)  # seule la première année visible au départ
            )
        )

    # Création des étapes du slider
    steps = []
    for i, year in enumerate(years):
        step = dict(
            method="update",
            args=[{"visible": [j==i for j in range(len(traces))]}],
            label=str(year)
        )
        steps.append(step)
    
    # Slider
    sliders = [dict(
        active=0,
        currentvalue={"prefix": "Année: ", "font": {"size": 12}},
        pad={"t": 20},
        steps=steps
    )]

    fig = go.Figure(data=traces)
    fig.update_layout(
        title_text=f"{indicator} par année",
        geo=dict(
            scope="world",
            projection_type="natural earth",
            showcountries=True,
            showcoastlines=True,
            showland=True,
            landcolor="lightgray",
            fitbounds="locations"
        ),
        sliders=sliders,
        margin={"r":0, "t":50, "l":0, "b":0}
    )
    
    # Sauvegarder et/ou ouvrir automatiquement
    if save:
        # Récupérer la date au format YYYYMMDD
        # Nom du fichier avec la date
        fig.write_html(output_path)
        fig.write_html(output_path, include_plotlyjs='cdn')
        print(f"Carte interactive sauvegardée dans {output_path}")
    
    webbrowser.open_new_tab(output_path)

# %%
import webbrowser

# Nom du fichier HTML de sortie
output_file = "map_LULUCF_slider_light"

# Appel de la fonction avec slider pour l'année
plot_world_map_with_slider(
    df_data[df_data['Year'].isin([1980,1990,2000,2010,2020])],
    gdf_world=gdf_world,
    indicator="LULUCF Net emissions",
    output_html=output_file,
    save=True,
    base_path=base_path
)
# Out:
# Carte interactive sauvegardée dans C:\Users\Aubin\Documents\NetZero\Figures\map_LULUCF_slider_light_20251112.html

# %%
df_data
# Out:
#       countryiso3  Year     country  gdp_percapita_current_usd  \
# 0              1A  1960  Arab World                        NaN
# 1              1A  1961  Arab World                 212.889663
# 2              1A  1962  Arab World                 210.805415
# 3              1A  1963  Arab World                 225.800630
# 4              1A  1964  Arab World                 243.897432
# ...           ...   ...         ...                        ...
# 17285          ZW  2020    Zimbabwe                1730.453910
# 17286          ZW  2021    Zimbabwe                1724.387271
# 17287          ZW  2022    Zimbabwe                2040.546587
# 17288          ZW  2023    Zimbabwe                2156.034093
# 17289          ZW  2024    Zimbabwe                2656.409377
#
#        gdp_percapita_ppp_current_intl  missing_population_total  \
# 0                                 NaN                     False
# 1                                 NaN                     False
# 2                                 NaN                     False
# 3                                 NaN                     False
# 4                                 NaN                     False
# ...                               ...                       ...
# 17285                     3510.676040                     False
# 17286                     3184.784602                     False
# 17287                     3560.039403                     False
# 17288                     3820.359922                     False
# 17289                     3921.697956                     False
#
#        missing_gdp_current_usd  missing_gdp_percapita_current_usd  \
# 0                         True                               True
# 1                        False                              False
# 2                        False                              False
# 3                        False                              False
# 4                        False                              False
# ...                        ...                                ...
# 17285                    False                              False
# 17286                    False                              False
# 17287                    False                              False
# 17288                    False                              False
# 17289                    False                              False
#
#        missing_gdp_ppp_current_intl  missing_gdp_percapita_ppp_current_intl  \
# 0                              True                                    True
# 1                              True                                    True
# 2                              True                                    True
# 3                              True                                    True
# 4                              True                                    True
# ...                             ...                                     ...
# 17285                         False                                   False
# 17286                         False                                   False
# 17287                         False                                   False
# 17288                         False                                   False
# 17289                         False                                   False
#
#        ...  Value_norm_gdp  Unit_norm_gdp  Value_norm_ppp  Unit_norm_ppp  \
# 0      ...             NaN   /billion USD             NaN  /billion PPP$
# 1      ...       19.997084   /billion USD             NaN  /billion PPP$
# 2      ...       20.327671   /billion USD             NaN  /billion PPP$
# 3      ...       22.362958   /billion USD             NaN  /billion PPP$
# 4      ...       24.811627   /billion USD             NaN  /billion PPP$
# ...    ...             ...            ...             ...            ...
# 17285  ...       26.868564   /billion USD       54.509874  /billion PPP$
# 17286  ...       27.240508   /billion USD       50.310711  /billion PPP$
# 17287  ...       32.789657   /billion USD       57.206473  /billion PPP$
# 17288  ...       35.231369   /billion USD       62.427821  /billion PPP$
# 17289  ...       44.187704   /billion USD       65.234987  /billion PPP$
#
#        Value_norm_gdp_hab  Unit_norm_gdp_hab  Value_norm_ppp_hab  \
# 0                     NaN  /thousand USD/hab                 NaN
# 1                0.212890  /thousand USD/hab                 NaN
# 2                0.210805  /thousand USD/hab                 NaN
# 3                0.225801  /thousand USD/hab                 NaN
# 4                0.243897  /thousand USD/hab                 NaN
# ...                   ...                ...                 ...
# 17285            1.730454  /thousand USD/hab            3.510676
# 17286            1.724387  /thousand USD/hab            3.184785
# 17287            2.040547  /thousand USD/hab            3.560039
# 17288            2.156034  /thousand USD/hab            3.820360
# 17289            2.656409  /thousand USD/hab            3.921698
#
#         Unit_norm_ppp_hab  Value_norm_densite Unit_norm_densite
# 0      /thousand PPP$/hab                 NaN          /hab/km²
# 1      /thousand PPP$/hab            8.360295          /hab/km²
# 2      /thousand PPP$/hab            8.582530          /hab/km²
# 3      /thousand PPP$/hab            8.814823          /hab/km²
# 4      /thousand PPP$/hab            9.054355          /hab/km²
# ...                   ...                 ...               ...
# 17285  /thousand PPP$/hab           40.136714          /hab/km²
# 17286  /thousand PPP$/hab           40.835492          /hab/km²
# 17287  /thousand PPP$/hab           41.538209          /hab/km²
# 17288  /thousand PPP$/hab           42.240719          /hab/km²
# 17289  /thousand PPP$/hab                 NaN          /hab/km²
#
# [17290 rows x 28 columns]

# %% [markdown]
# ## with button / normalisation

# %%
import plotly.graph_objects as go
import pandas as pd
import geopandas as gpd
import json
import webbrowser
from pathlib import Path
from datetime import datetime
import numpy as np

def symlog(x):
    """Logarithme symétrique : log10(|x|+1) * signe(x)"""
    if pd.isna(x):
        return None
    return np.sign(x) * np.log10(abs(x) + 1)

def plot_world_map_button(df_data, gdf_world, indicator,database, year,
                          output_html="map_buttons",
                          save=True,
                          base_path=Path('C:/Users/Aubin/Documents/NetZero'),
                          scale="relative",
                          color_range="raw",
                          color_map="RdYlGn_r"):

    # --- Préparer sortie ---
    date_str = datetime.now().strftime("%Y%m%d")
    output_html = f"{output_html}_{scale}_{color_range}_{date_str}.html"
    output_path = base_path / 'Figures' / output_html
    output_path.parent.mkdir(parents=True, exist_ok=True)

    # --- Nettoyer gdf_world ---
    gdf_world = gdf_world[gdf_world["Country_code"].notna()].copy()

    # --- Filtrer indicateur et année ---
    df_filtered = df_data[(df_data['Indicator'] == indicator) & (df_data['Source'] == database) & (df_data['Year'] == year)].copy()
    # --- Fusion avec GeoDataFrame ---
    gdf_merged = gdf_world.merge(df_filtered, on='Country_code', how='left')
    geojson_data = json.loads(gdf_merged.to_json())

    # --- Normalisations et colonnes d'unité ---
    norm_map = {
        'No norm': ('Value', 'Unit'),
        'Area': ('Value_norm_area', 'Unit_norm_area'),         # area / million km²
        'Population': ('Value_norm_population', 'Unit_norm_population'),  # population / million inhabitants
        'Hab/km2': ('Value_norm_densite', 'Unit_norm_densite'),   # population density / hab/km²
        'PPP': ('Value_norm_ppp', 'Unit_norm_ppp'),           # GDP PPP total / billion PPP$
        'GDP': ('Value_norm_gdp', 'Unit_norm_gdp'),           # GDP total / billion USD
        'PPP/hab': ('Value_norm_ppp_hab', 'Unit_norm_ppp_hab'),  # GDP PPP per capita / thousand PPP$/hab
        'GDP/hab': ('Value_norm_gdp_hab', 'Unit_norm_gdp_hab')  # GDP per capita / thousand USD/hab
    }

    # Colonne pour le hover : la valeur brute issue de df_filtered
    #hover_values = gdf_merged[col_value]  # col_value correspond à la colonne "Value" ou normalisée

    # --- Fonction pour bornes de couleur ---
    def compute_zrange(col_values):
        if color_range == 'raw':
            zmin, zmax = col_values.min(), col_values.max()
            print(f"[Color range] Mode = raw → zmin = {zmin:.4g}, zmax = {zmax:.4g}")
            return zmin, zmax, col_values
    
        elif color_range.startswith("q"):
            try:
                q_low = float(color_range[1:])  # lire tout après 'q'
            except ValueError:
                raise ValueError("Invalid format for quantile range. Use e.g. 'q0.01', 'q0.05', 'q0.1'.")
            q_high = 1 - q_low
            zmin, zmax = col_values.quantile(q_low), col_values.quantile(q_high)
            print(f"[Color range] Mode = quantile {q_low:.2%}–{q_high:.2%} → zmin = {zmin:.4g}, zmax = {zmax:.4g}")
            return zmin, zmax, col_values
    
        elif color_range.startswith("*"):
            try:
                factor = float(color_range[1:])
            except ValueError:
                raise ValueError("Invalid format for scaling factor. Use e.g. '*0.8' or '*1.2'.")
            zmin, zmax = factor * col_values.min(), factor * col_values.max()
            print(f"[Color range] Mode = scaled ×{factor:.3g} → zmin = {zmin:.4g}, zmax = {zmax:.4g}")
            return zmin, zmax, col_values
    
        else:
            raise ValueError("color_range must be 'raw', 'q0.xx', or '*0.xx'")



    # --- Créer toutes les traces (une par normalisation) ---
    traces = []
    for norm_name, (col_value, col_unit) in norm_map.items():
        zmin, zmax, z_values = compute_zrange(gdf_merged[col_value])
        unit_val = gdf_merged[col_unit].iloc[0] if col_unit in df_filtered.columns else ""
        colorbar_title = f"{unit_val}"
        z_plot = z_values.copy()

        if scale == 'rank':
            ranks = gdf_merged[col_value]
            mask = ranks.notna()
            ranks[mask] = ranks[mask].rank(ascending=True)
            
            trace = go.Choropleth(
                geojson=geojson_data,
                locations=gdf_merged.index,
                z=ranks,
                text=gdf_merged['name'],
                colorscale=color_map,
                zmin=ranks.min(),
                zmax=ranks.max(),
                customdata=gdf_merged[col_value],
                colorbar_title=f"{colorbar_title} (Rank)",
                colorbar=dict(title=colorbar_title, x=0.02, xanchor='left'),
                hovertemplate = (f"<b>%{{text}}</b><br>{indicator} ({norm_name}) = %{{customdata:.2f}} {unit_val}<extra></extra>"),
                visible=(norm_name == "No norm"),
                name=norm_name
            )

        elif scale == 'absolute':
            # Générer 8 ticks inclusifs (min et max compris)
            N_ticks = 8
            tickvals = np.linspace(zmin, zmax, N_ticks)

            # Si les bornes sont proches d'entiers, arrondir
            tickvals_rounded = np.round(tickvals).astype(int) if (abs(zmax - zmin) > 10) else np.round(tickvals, 2)
            ticktext = [str(v) for v in tickvals_rounded]

            # Déterminer la borne max symétrique autour de 0
            zborne = max(abs(zmin), abs(zmax))
            zmid = 0

            # Définir la colorbar
            colorbar_dict = dict(
                title=f"({unit_val})",
                tickvals=tickvals,
                ticktext=ticktext,
                x=0.02,
                xanchor='left',
                y=0.5,
                yanchor='middle'
            )

            trace = go.Choropleth(
                geojson=geojson_data,
                locations=gdf_merged.index,
                z=z_plot,
                text=gdf_merged['name'],
                colorscale=color_map,
                zmin=-zborne,
                zmax=zborne,
                zmid=zmid,
                customdata=gdf_merged[col_value],
                colorbar_title=colorbar_title,
                colorbar=colorbar_dict,
                hovertemplate=(
                    f"<b>%{{text}}</b><br>"
                    f"{indicator} ({norm_name}) = %{{customdata:.2f}} {unit_val}"
                    "<extra></extra>"
                ),
                visible=(norm_name == "No norm"),
                name=norm_name
            )

        elif scale == 'relative':
            # Ticks arrondis avec min/max inclus
            N_ticks = 8
            tickvals = np.linspace(zmin, zmax, N_ticks)
            tickvals_rounded = np.round(tickvals).astype(int) if (abs(zmax - zmin) > 10) else np.round(tickvals, 2)
            ticktext = [str(v) for v in tickvals_rounded]

            colorbar_dict = dict(
                title=f"({unit_val})",
                tickvals=tickvals,
                ticktext=ticktext,
                x=0.02,
                xanchor='left',
                y=0.5,
                yanchor='middle'
            )

            trace = go.Choropleth(
                geojson=geojson_data,
                locations=gdf_merged.index,
                z=z_plot,
                text=gdf_merged['name'],
                colorscale=color_map,
                zmin=zmin,
                zmax=zmax,
                customdata=gdf_merged[col_value],
                colorbar=colorbar_dict,
                colorbar_title=colorbar_title,
                hovertemplate = (
                    f"<b>%{{text}}</b><br>"
                    f"{indicator} ({norm_name}) = %{{customdata:.2f}} {unit_val}"
                    "<extra></extra>"
                ),
                visible=(norm_name == "No norm"),
                name=norm_name
            )

        elif scale == 'log':
            z_log = z_plot.apply(symlog)
            trace = go.Choropleth(
                geojson=geojson_data,
                locations=gdf_merged.index,
                z=z_log,
                customdata=gdf_merged[col_value],
                text=gdf_merged['name'],
                colorscale=color_map,
                colorbar_title=f"{colorbar_title} (symlog10)",
                colorbar=dict(title=colorbar_title, x=0.02, xanchor='left'),
                hovertemplate = (f"<b>%{{text}}</b><br>{indicator} ({norm_name}) = %{{customdata:.2f}} {unit_val}<extra></extra>"),
                visible=(norm_name == "No norm"),
                name=norm_name
            )

        else:
            raise ValueError("scale must be 'absolute', 'relative','rank' or 'log'")

        traces.append(trace)

    # --- Trace spéciale pour "No data" dans la légende ---
    trace_nodata_legend = go.Scattergeo(
        lon=[None],  # aucune donnée géographique réelle
        lat=[None],
        mode='markers',
        marker=dict(size=20, color='lightgray', line=dict(width=0.5, color='black')),
        name='No data',
        showlegend=True
    )
    traces.append(trace_nodata_legend)


    # --- Boutons pour normalisation (titre reste constant) ---
    buttons = []
    for i, norm_name in enumerate(norm_map.keys()):
        visible_list = [False] * len(traces)
        visible_list[i] = True
        visible_list[-1] = True 
        buttons.append(dict(
            label=norm_name,
            method="update",
            args=[{"visible": visible_list}]
        ))

    updatemenus = [dict(
        active=0,
        buttons=buttons,
        x=0.0,
        y=1.05,
        xanchor='left',
        yanchor='top'
    )]

    # --- Création figure ---
    subtitle = f"Scale: {scale}, Color range: {color_range}"
    fig = go.Figure(data=traces)
    fig.update_layout(
        dragmode=False,
        title=dict(
            text=f"<b>{indicator} - {database} - Année {year}</b><br><sup>{subtitle}</sup>",
            x=0.5,
            xanchor='center',
            y=0.98,        # plus proche du haut (1.0 = bord supérieur)
            yanchor='top',
            font=dict(size=26, family="Arial, Bold", color="black"),
            pad=dict(t=0, b=0)  # supprime le padding interne du titre
        ),
        geo=dict(
            scope="world",
            projection_type="natural earth",
            showcountries=True,
            showcoastlines=True,
            showland=True,
            showocean=True,
            landcolor="lightgray",
            oceancolor="lightblue",
            lakecolor="lightblue",
            fitbounds="locations",
            center=dict(lat=100, lon=0),
        ),
        updatemenus=updatemenus,
        legend=dict(
            x=0.07,
            y=0.95,
            xanchor="left",
            yanchor="top",
            bgcolor="rgba(255,255,255,0.7)",
            bordercolor="gray",
            borderwidth=0.5
        ),
        height=None,
        autosize=True,
        margin={"r": 0, "t": 0, "l": 0, "b": 20}  # supprime toutes les marges
    )

    # --- Sauvegarde et ouverture ---
    if save:
        fig.write_html(output_path, include_plotlyjs='cdn')
        print(f"Carte interactive sauvegardée dans {output_path}")
        webbrowser.open_new_tab(output_path)

# %%
import webbrowser

# Nom du fichier HTML de sortie
output_file = "map_LULUCF_norm"

# Appel de la fonction avec slider pour l'année
plot_world_map_button(
    df_data,
    gdf_world=gdf_world,
    indicator="LULUCF Net emissions",
    database="GCB",
    year=2020,
    output_html=output_file,
    save=True,
    base_path=base_path,
    scale="relative", #absolute, relative, log, rank
    color_range='q0.01', #raw, q0.01, *0.9
    color_map="RdYlGn_r" #RdYlGn_r YlOrBr
)
# Out:
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -11.33, zmax = 118.3
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -33.96, zmax = 62.2
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -0.3109, zmax = 1.623
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -0.0551, zmax = 5.08
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -0.03, zmax = 0.45
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -0.07023, zmax = 0.8565
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -0.4984, zmax = 14.5
# [Color range] Mode = quantile 1.00%–99.00% → zmin = -0.8255, zmax = 42.78
# Carte interactive sauvegardée dans C:\Users\Aubin\Documents\NetZero\Figures\map_LULUCF_norm_relative_q0.01_20251113.html
