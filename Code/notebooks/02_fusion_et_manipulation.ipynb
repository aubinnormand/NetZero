# %% [markdown]
# ## Importation des données

# %%
import sys
from pathlib import Path
import importlib
import ipynbname 
import pandas as pd
import geopandas as gpd
from datetime import datetime

code_path = ipynbname.path().parent.parent
# Ajouter le dossier scripts au path
scripts_path = code_path  / "scripts"
base_path=code_path.parent
sys.path.append(str(scripts_path.resolve()))

import data_utils  # importe le module une première fois

# Après avoir modifié data_utils.py
importlib.reload(data_utils)

# Maintenant tu peux accéder aux fonctions mises à jour
from data_utils import import_data_raw, import_data_sig, melt_long_format, clean_year_column, save_long_dataframe, concat_intermediate_files

# %%
#Country data
filename="data_final_all.csv"
filepath= base_path/ "Data" / 'data_final' / filename

df_data = pd.read_csv(filepath)
df_data.head()
# Out:
#    Year  Country         Value Unit     Category    Indicator Source  \
# 0  1990  Albania  1.520044e+06   tC  Fossil Fuel  Consumption    GCB
# 1  1991  Albania  1.258935e+06   tC  Fossil Fuel  Consumption    GCB
# 2  1992  Albania  7.976992e+05   tC  Fossil Fuel  Consumption    GCB
# 3  1993  Albania  7.294902e+05   tC  Fossil Fuel  Consumption    GCB
# 4  1994  Albania  6.450812e+05   tC  Fossil Fuel  Consumption    GCB
#
#   Country_code    Type
# 0           AL  Annual
# 1           AL  Annual
# 2           AL  Annual
# 3           AL  Annual
# 4           AL  Annual

# %%
#Global sig
gdf_world=import_data_sig(base_path,'world.geojson')
gdf_world.head()
# Out:
#                                         geo_point_2d  iso3        status  \
# 0  { "lon": -16.984917430414384, "lat": 32.747916...  None  PT Territory
# 1  { "lon": 33.743791080217562, "lat": 21.8927401...  None   Adm. by EGY
# 2  { "lon": 9.5613358449883421, "lat": 34.1108585...   TUN  Member State
# 3  { "lon": 43.77213543247138, "lat": 33.04802449...   IRQ  Member State
# 4  { "lon": -6.3178452255610269, "lat": 31.883624...   MAR  Member State
#
#   color_code             name continent           region Country_code  \
# 0        PRT  Madeira Islands    Europe  Southern Europe         None
# 1        EGY  Ma'tan al-Sarra    Africa  Northern Africa         None
# 2        TUN          Tunisia    Africa  Northern Africa           TN
# 3        IRQ             Iraq      Asia     Western Asia           IQ
# 4        MAR          Morocco    Africa  Northern Africa           MA
#
#       french_short  Country                                           geometry
# 0  Madeira Islands     None  POLYGON ((-17.1025 32.82333, -17.05306 32.8094...
# 1  Ma'tan al-Sarra     None  POLYGON ((33.25104 21.99977, 34.15064 21.99603...
# 2          Tunisie  Tunisia  MULTIPOLYGON (((10.99361 33.75, 10.93778 33.72...
# 3             Iraq     Iraq  POLYGON ((44.78734 37.14971, 44.76617 37.11228...
# 4            Maroc  Morocco  POLYGON ((-2.94694 35.32916, -2.96618 35.31663...

# %%
# Fetch data from world bank
from pathlib import Path
import requests
import pandas as pd
import time

# --- Chemin de sortie ---
filepath = base_path/ "Data" / "countries"
filepath.mkdir(parents=True, exist_ok=True)  # crée le dossier si inexistant
output_file = filepath / "countries_wdi_raw.csv"

# --- Paramètres WDI ---
WDI_BASE = "https://api.worldbank.org/v2"
INDICATORS = {
    "SP.POP.TOTL": "population_total",
    "NY.GDP.MKTP.CD": "gdp_current_usd",
    "NY.GDP.PCAP.CD": "gdp_percapita_current_usd",
    "NY.GDP.MKTP.PP.CD": "gdp_ppp_current_intl",
    "NY.GDP.PCAP.PP.CD": "gdp_percapita_ppp_current_intl"
}
START_YEAR = 1850
END_YEAR = 2025
PER_PAGE = 20000

# --- Fonction pour récupérer un indicateur ---
def fetch_indicator(indicator, start=START_YEAR, end=END_YEAR):
    rows = []
    page = 1
    while True:
        url = f"{WDI_BASE}/country/all/indicator/{indicator}"
        params = {"format": "json", "per_page": PER_PAGE, "page": page, "date": f"{start}:{end}"}
        r = requests.get(url, params=params)
        if r.status_code != 200:
            raise RuntimeError(f"Erreur HTTP {r.status_code} pour {indicator} page {page}")
        data = r.json()
        if not isinstance(data, list) or len(data) < 2:
            break
        meta, records = data[0], data[1]
        for item in records:
            rows.append({
                "country": item["country"]["value"],
                "countryiso3": item["country"]["id"],
                "Year": int(item["date"]),
                "value": None if item["value"] is None else float(item["value"])
            })
        total_pages = int(meta.get("pages", 1))
        if page >= total_pages:
            break
        page += 1
        time.sleep(0.2)
    return pd.DataFrame(rows)

# --- Télécharger les indicateurs ---
dfs = {}
for code, name in INDICATORS.items():
    print(f"Téléchargement de {code} ...")
    df = fetch_indicator(code)
    df = df.rename(columns={"value": name})
    dfs[name] = df

# --- Construire tableau complet pays x année ---
countries = pd.concat([df[['country','countryiso3']].drop_duplicates() for df in dfs.values()]).drop_duplicates()
years = list(range(START_YEAR, END_YEAR + 1))
cart = pd.MultiIndex.from_product([countries['countryiso3'], years], names=['countryiso3','Year']).to_frame(index=False)
cart['country'] = cart['countryiso3'].map(countries.set_index('countryiso3')['country'])

df_all = cart.copy()
for name, df in dfs.items():
    df_all = df_all.merge(df[['countryiso3','Year', name]], on=['countryiso3','Year'], how='left')

# --- Ajouter colonne de manquants ---
for name in INDICATORS.values():
    df_all[f"missing_{name}"] = df_all[name].isna()

# --- Sauvegarder ---
df_all = df_all.sort_values(['countryiso3','Year']).reset_index(drop=True)
df_all.to_csv(output_file, index=False, encoding="utf-8")

print(f"\n✅ Données enregistrées dans {output_file}")
print("Colonnes disponibles :", ", ".join(df_all.columns))
print(f"Nombre total de lignes : {len(df_all):,}")
# Out:
# Téléchargement de SP.POP.TOTL ...
# Téléchargement de NY.GDP.MKTP.CD ...
# Téléchargement de NY.GDP.PCAP.CD ...
# Téléchargement de NY.GDP.MKTP.PP.CD ...
# Téléchargement de NY.GDP.PCAP.PP.CD ...
#
# ✅ Données enregistrées dans C:\Users\User 1\Documents\NetZero\NetZero\Data\countries\countries_wdi_raw.csv
# Colonnes disponibles : countryiso3, Year, country, population_total, gdp_current_usd, gdp_percapita_current_usd, gdp_ppp_current_intl, gdp_percapita_ppp_current_intl, missing_population_total, missing_gdp_current_usd, missing_gdp_percapita_current_usd, missing_gdp_ppp_current_intl, missing_gdp_percapita_ppp_current_intl
# Nombre total de lignes : 46,816

# %%
df_all
# Out:
#       countryiso3  Year     country  population_total  gdp_current_usd  \
# 0              1A  1850  Arab World               NaN              NaN
# 1              1A  1851  Arab World               NaN              NaN
# 2              1A  1852  Arab World               NaN              NaN
# 3              1A  1853  Arab World               NaN              NaN
# 4              1A  1854  Arab World               NaN              NaN
# ...           ...   ...         ...               ...              ...
# 46811          ZW  2021    Zimbabwe        15797210.0     2.724051e+10
# 46812          ZW  2022    Zimbabwe        16069056.0     3.278966e+10
# 46813          ZW  2023    Zimbabwe        16340822.0     3.523137e+10
# 46814          ZW  2024    Zimbabwe        16634373.0     4.418770e+10
# 46815          ZW  2025    Zimbabwe               NaN              NaN
#
#        gdp_percapita_current_usd  gdp_ppp_current_intl  \
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# ...                          ...                   ...
# 46811                1724.387271          5.031071e+10
# 46812                2040.546587          5.720647e+10
# 46813                2156.034093          6.242782e+10
# 46814                2656.409377          6.523499e+10
# 46815                        NaN                   NaN
#
#        gdp_percapita_ppp_current_intl  missing_population_total  \
# 0                                 NaN                      True
# 1                                 NaN                      True
# 2                                 NaN                      True
# 3                                 NaN                      True
# 4                                 NaN                      True
# ...                               ...                       ...
# 46811                     3184.784602                     False
# 46812                     3560.039403                     False
# 46813                     3820.359922                     False
# 46814                     3921.697956                     False
# 46815                             NaN                      True
#
#        missing_gdp_current_usd  missing_gdp_percapita_current_usd  \
# 0                         True                               True
# 1                         True                               True
# 2                         True                               True
# 3                         True                               True
# 4                         True                               True
# ...                        ...                                ...
# 46811                    False                              False
# 46812                    False                              False
# 46813                    False                              False
# 46814                    False                              False
# 46815                     True                               True
#
#        missing_gdp_ppp_current_intl  missing_gdp_percapita_ppp_current_intl
# 0                              True                                    True
# 1                              True                                    True
# 2                              True                                    True
# 3                              True                                    True
# 4                              True                                    True
# ...                             ...                                     ...
# 46811                         False                                   False
# 46812                         False                                   False
# 46813                         False                                   False
# 46814                         False                                   False
# 46815                          True                                    True
#
# [46816 rows x 13 columns]

# %%
# Fetch data from world bank
from pathlib import Path
import requests
import pandas as pd
import time

# --- Chemin de sortie ---
filepath = base_path/ "Data" / "countries"
filepath.mkdir(parents=True, exist_ok=True)  # crée le dossier si inexistant
output_file = filepath / "countries_wdi_raw.csv"

# --- Paramètres WDI ---
INDICATORS = {
    "SP.POP.TOTL": "population_total",
    "NY.GDP.MKTP.CD": "gdp_current_usd",
    "NY.GDP.PCAP.CD": "gdp_percapita_current_usd",
    "NY.GDP.MKTP.PP.CD": "gdp_ppp_current_intl",
    "NY.GDP.PCAP.PP.CD": "gdp_percapita_ppp_current_intl",
    "AG.LND.TOTL.K2": "area_km2"   # <-- ajout superficie
}
# --- Télécharger les indicateurs ---
dfs = {}
for code, name in INDICATORS.items():
    print(f"Téléchargement de {code} ...")
    df = fetch_indicator(code)
    df = df.rename(columns={"value": name})
    dfs[name] = df

# --- Construire tableau complet pays x année ---
countries = pd.concat([df[['country','countryiso3']].drop_duplicates() for df in dfs.values()]).drop_duplicates()
years = list(range(START_YEAR, END_YEAR + 1))
cart = pd.MultiIndex.from_product([countries['countryiso3'], years], names=['countryiso3','Year']).to_frame(index=False)
cart['country'] = cart['countryiso3'].map(countries.set_index('countryiso3')['country'])

df_all = cart.copy()
for name, df in dfs.items():
    df_all = df_all.merge(df[['countryiso3','Year', name]], on=['countryiso3','Year'], how='left')

# --- Ajouter colonne de manquants ---
for name in INDICATORS.values():
    df_all[f"missing_{name}"] = df_all[name].isna()

# --- Calculs supplémentaires ---
df_all['gdp_ppp_percapita_calc'] = df_all['gdp_ppp_current_intl'] / df_all['population_total']
df_all['population_density'] = df_all['population_total'] / df_all['area_km2']

## --- Remplacer countryiso3 pour Namibia ---
df_all.loc[df_all['country'] == "Namibia", 'countryiso3'] = "NAM"

# --- Sauvegarder ---
df_all = df_all.sort_values(['countryiso3','Year']).reset_index(drop=True)
df_all.to_csv(output_file, index=False, encoding="utf-8")

print(f"\n✅ Données enregistrées dans {output_file}")
print("Colonnes disponibles :", ", ".join(df_all.columns))
print(f"Nombre total de lignes : {len(df_all):,}")
# Out:
# Téléchargement de SP.POP.TOTL ...
# Téléchargement de NY.GDP.MKTP.CD ...
# Téléchargement de NY.GDP.PCAP.CD ...
# Téléchargement de NY.GDP.MKTP.PP.CD ...
# Téléchargement de NY.GDP.PCAP.PP.CD ...
# Téléchargement de AG.LND.TOTL.K2 ...
#
# ✅ Données enregistrées dans C:\Users\User 1\Documents\NetZero\NetZero\Data\countries\countries_wdi_raw.csv
# Colonnes disponibles : countryiso3, Year, country, population_total, gdp_current_usd, gdp_percapita_current_usd, gdp_ppp_current_intl, gdp_percapita_ppp_current_intl, area_km2, missing_population_total, missing_gdp_current_usd, missing_gdp_percapita_current_usd, missing_gdp_ppp_current_intl, missing_gdp_percapita_ppp_current_intl, missing_area_km2, gdp_ppp_percapita_calc, population_density
# Nombre total de lignes : 46,816

# %%
import pandas as pd
from pathlib import Path
import ipynbname

# --- Paths ---
code_path = ipynbname.path().parent.parent
base_path = code_path.parent
data_path = base_path / "Data" / "countries"

# --- Load WDI data ---
df_wdi = pd.read_csv(data_path / "countries_wdi_raw.csv")

# --- Compute derived indicators ---
df_wdi['gdp_percapita'] = df_wdi['gdp_current_usd'] / df_wdi['population_total']
df_wdi['gdp_ppp_percapita'] = df_wdi['gdp_ppp_current_intl'] / df_wdi['population_total']
df_wdi['population_density'] = df_wdi['population_total'] / df_wdi['area_km2']

# --- Normalisation specifications ---
norm_specs = {
    'area': ('area_km2', 1, '/km²'),
    'population': ('population_total', 1e1, '/hab'),
    'gdp': ('gdp_current_usd', 1e6, '/GDP M$'),
    'ppp': ('gdp_ppp_current_intl', 1e6, '/GDP(PPP) M$'),
    'gdp_hab': ('gdp_percapita', 1e3, '/k$/hab'),
    'ppp_hab': ('gdp_ppp_percapita', 1e3, '/k$(PPP)/hab'),
    'densite': ('population_density', 1, '/hab/km²')
}

# --- Load your data ---
filename="data_final_all.csv"
filepath= base_path/ "Data" / 'data_final' / filename
df_data = pd.read_csv(filepath)# Year, Country, Value, Unit, Indicator, Source, Country_code
df_data.head()
#
# Out:
#    Year  Country         Value Unit     Category    Indicator Source  \
# 0  1990  Albania  1.520044e+06   tC  Fossil Fuel  Consumption    GCB
# 1  1991  Albania  1.258935e+06   tC  Fossil Fuel  Consumption    GCB
# 2  1992  Albania  7.976992e+05   tC  Fossil Fuel  Consumption    GCB
# 3  1993  Albania  7.294902e+05   tC  Fossil Fuel  Consumption    GCB
# 4  1994  Albania  6.450812e+05   tC  Fossil Fuel  Consumption    GCB
#
#   Country_code    Type
# 0           AL  Annual
# 1           AL  Annual
# 2           AL  Annual
# 3           AL  Annual
# 4           AL  Annual

# %%
 #--- Merge df_data with WDI ---
df_norm = df_data.merge(df_wdi, left_on=['Country_code','Year'], right_on=['countryiso3','Year'], how='left')

# --- Apply all normalizations dynamically ---
for norm, (col_ref, divisor, unit_suffix) in norm_specs.items():
    val_col = f"Value_norm_{norm}"
    unit_col = f"Unit_norm_{norm}"
    # Normalize: df_data Value relative to the reference column
    df_norm[val_col] = df_norm['Value'] / (df_norm[col_ref] / divisor)
    df_norm[unit_col] = df_norm['Unit'] + unit_suffix

# --- Handle missing / infinite values ---
for col in [f"Value_norm_{n}" for n in norm_specs.keys()]:
    df_norm[col] = df_norm[col].replace([float('inf'), -float('inf')], pd.NA)

# --- Drop intermediate WDI columns if desired ---
drop_cols = [c for c in df_wdi.columns if c not in ['countryiso3','Year']]
df_final = df_norm.drop(columns=drop_cols)

# --- Drop intermediate columns ---
df_final = df_norm.drop(columns=['area_km2','countryiso3','population_total','gdp_current_usd','gdp_ppp_current_intl'])

output_dir = base_path / 'Data' / 'data_final'
output_dir.mkdir(parents=True, exist_ok=True)
output_file = output_dir / "data_final_all_norm.csv"
df_final.to_csv(output_file, index=False, encoding='utf-8')

print(f"✅ All normalizations applied and saved to {output_file}")
print(df_final.head())
# Out:
# ✅ All normalizations applied and saved to C:\Users\User 1\Documents\NetZero\NetZero\Data\data_final\data_final_all_norm.csv
#    Year  Country         Value Unit     Category    Indicator Source  \
# 0  1990  Albania  1.520044e+06   tC  Fossil Fuel  Consumption    GCB
# 1  1991  Albania  1.258935e+06   tC  Fossil Fuel  Consumption    GCB
# 2  1992  Albania  7.976992e+05   tC  Fossil Fuel  Consumption    GCB
# 3  1993  Albania  7.294902e+05   tC  Fossil Fuel  Consumption    GCB
# 4  1994  Albania  6.450812e+05   tC  Fossil Fuel  Consumption    GCB
#
#   Country_code    Type  country  ...  Value_norm_gdp  Unit_norm_gdp  \
# 0           AL  Annual  Albania  ...      749.323963      tC/GDP M$
# 1           AL  Annual  Albania  ...     1144.945449      tC/GDP M$
# 2           AL  Annual  Albania  ...     1223.136755      tC/GDP M$
# 3           AL  Annual  Albania  ...      615.439686      tC/GDP M$
# 4           AL  Annual  Albania  ...      342.954824      tC/GDP M$
#
#   Value_norm_ppp   Unit_norm_ppp Value_norm_gdp_hab Unit_norm_gdp_hab  \
# 0     174.197786  tC/GDP(PPP) M$       2.462685e+06         tC/k$/hab
# 1     193.832286  tC/GDP(PPP) M$       3.740296e+06         tC/k$/hab
# 2     129.380190  tC/GDP(PPP) M$       3.971573e+06         tC/k$/hab
# 3     105.493161  tC/GDP(PPP) M$       1.986200e+06         tC/k$/hab
# 4      84.334220  tC/GDP(PPP) M$       1.100040e+06         tC/k$/hab
#
#   Value_norm_ppp_hab Unit_norm_ppp_hab  Value_norm_densite  Unit_norm_densite
# 0      572508.339337    tC/k$(PPP)/hab        12672.652230         tC/hab/km²
# 1      633209.374503    tC/k$(PPP)/hab        10559.240682         tC/hab/km²
# 2      420102.524067    tC/k$(PPP)/hab         6731.350668         tC/hab/km²
# 3      340456.706646    tC/k$(PPP)/hab         6193.446979         tC/hab/km²
# 4      270505.047381    tC/k$(PPP)/hab         5510.530246         tC/hab/km²
#
# [5 rows x 36 columns]

# %%
df_wdi[df_wdi["country"]=="Namibia"]
# Out:
#       countryiso3  Year  country  population_total  gdp_current_usd  \
# 26048         NAM  1850  Namibia               NaN              NaN
# 26049         NAM  1851  Namibia               NaN              NaN
# 26050         NAM  1852  Namibia               NaN              NaN
# 26051         NAM  1853  Namibia               NaN              NaN
# 26052         NAM  1854  Namibia               NaN              NaN
# ...           ...   ...      ...               ...              ...
# 26219         NAM  2021  Namibia         2810548.0     1.240249e+10
# 26220         NAM  2022  Namibia         2889662.0     1.256945e+10
# 26221         NAM  2023  Namibia         2963095.0     1.240827e+10
# 26222         NAM  2024  Namibia         3030131.0     1.337235e+10
# 26223         NAM  2025  Namibia               NaN              NaN
#
#        gdp_percapita_current_usd  gdp_ppp_current_intl  \
# 26048                        NaN                   NaN
# 26049                        NaN                   NaN
# 26050                        NaN                   NaN
# 26051                        NaN                   NaN
# 26052                        NaN                   NaN
# ...                          ...                   ...
# 26219                4412.835569          2.728789e+10
# 26220                4349.799085          3.081160e+10
# 26221                4187.605004          3.333848e+10
# 26222                4413.127442          3.541194e+10
# 26223                        NaN                   NaN
#
#        gdp_percapita_ppp_current_intl  area_km2  missing_population_total  \
# 26048                             NaN       NaN                      True
# 26049                             NaN       NaN                      True
# 26050                             NaN       NaN                      True
# 26051                             NaN       NaN                      True
# 26052                             NaN       NaN                      True
# ...                               ...       ...                       ...
# 26219                     9709.099306  823290.0                     False
# 26220                    10662.701705  823290.0                     False
# 26221                    11251.237033  823290.0                     False
# 26222                    11686.602062       NaN                     False
# 26223                             NaN       NaN                      True
#
#        missing_gdp_current_usd  missing_gdp_percapita_current_usd  \
# 26048                     True                               True
# 26049                     True                               True
# 26050                     True                               True
# 26051                     True                               True
# 26052                     True                               True
# ...                        ...                                ...
# 26219                    False                              False
# 26220                    False                              False
# 26221                    False                              False
# 26222                    False                              False
# 26223                     True                               True
#
#        missing_gdp_ppp_current_intl  missing_gdp_percapita_ppp_current_intl  \
# 26048                          True                                    True
# 26049                          True                                    True
# 26050                          True                                    True
# 26051                          True                                    True
# 26052                          True                                    True
# ...                             ...                                     ...
# 26219                         False                                   False
# 26220                         False                                   False
# 26221                         False                                   False
# 26222                         False                                   False
# 26223                          True                                    True
#
#        missing_area_km2  gdp_ppp_percapita_calc  population_density  \
# 26048              True                     NaN                 NaN
# 26049              True                     NaN                 NaN
# 26050              True                     NaN                 NaN
# 26051              True                     NaN                 NaN
# 26052              True                     NaN                 NaN
# ...                 ...                     ...                 ...
# 26219             False             9709.099306            3.413801
# 26220             False            10662.701705            3.509896
# 26221             False            11251.237033            3.599090
# 26222              True            11686.602062                 NaN
# 26223              True                     NaN                 NaN
#
#        gdp_percapita  gdp_ppp_percapita
# 26048            NaN                NaN
# 26049            NaN                NaN
# 26050            NaN                NaN
# 26051            NaN                NaN
# 26052            NaN                NaN
# ...              ...                ...
# 26219    4412.835569        9709.099306
# 26220    4349.799085       10662.701705
# 26221    4187.605004       11251.237033
# 26222    4413.127442       11686.602062
# 26223            NaN                NaN
#
# [176 rows x 19 columns]

# %%
df_final
# Out:
#         Year   Country         Value Unit     Category        Indicator  \
# 0       1990   Albania  1.520044e+06   tC  Fossil Fuel      Consumption
# 1       1991   Albania  1.258935e+06   tC  Fossil Fuel      Consumption
# 2       1992   Albania  7.976992e+05   tC  Fossil Fuel      Consumption
# 3       1993   Albania  7.294902e+05   tC  Fossil Fuel      Consumption
# 4       1994   Albania  6.450812e+05   tC  Fossil Fuel      Consumption
# ...      ...       ...           ...  ...          ...              ...
# 192449  2020  Zimbabwe  4.767382e+07   tC       LULUCF  Wood Harvesting
# 192450  2021  Zimbabwe  4.859141e+07   tC       LULUCF  Wood Harvesting
# 192451  2022  Zimbabwe  4.951711e+07   tC       LULUCF  Wood Harvesting
# 192452  2023  Zimbabwe  5.038698e+07   tC       LULUCF  Wood Harvesting
# 192453  2024  Zimbabwe  5.117530e+07   tC       LULUCF  Wood Harvesting
#
#        Source Country_code        Type   country  ...  Value_norm_gdp  \
# 0         GCB           AL      Annual   Albania  ...      749.323963
# 1         GCB           AL      Annual   Albania  ...     1144.945449
# 2         GCB           AL      Annual   Albania  ...     1223.136755
# 3         GCB           AL      Annual   Albania  ...      615.439686
# 4         GCB           AL      Annual   Albania  ...      342.954824
# ...       ...          ...         ...       ...  ...             ...
# 192449    GCB           ZW  Cumulative  Zimbabwe  ...     1774.334494
# 192450    GCB           ZW  Cumulative  Zimbabwe  ...     1783.792368
# 192451    GCB           ZW  Cumulative  Zimbabwe  ...     1510.144172
# 192452    GCB           ZW  Cumulative  Zimbabwe  ...     1430.173761
# 192453    GCB           ZW  Cumulative  Zimbabwe  ...     1158.134388
#
#         Unit_norm_gdp Value_norm_ppp   Unit_norm_ppp Value_norm_gdp_hab  \
# 0           tC/GDP M$     174.197786  tC/GDP(PPP) M$       2.462685e+06
# 1           tC/GDP M$     193.832286  tC/GDP(PPP) M$       3.740296e+06
# 2           tC/GDP M$     129.380190  tC/GDP(PPP) M$       3.971573e+06
# 3           tC/GDP M$     105.493161  tC/GDP(PPP) M$       1.986200e+06
# 4           tC/GDP M$      84.334220  tC/GDP(PPP) M$       1.100040e+06
# ...               ...            ...             ...                ...
# 192449      tC/GDP M$     874.590543  tC/GDP(PPP) M$       2.754989e+07
# 192450      tC/GDP M$     965.826340  tC/GDP(PPP) M$       2.817894e+07
# 192451      tC/GDP M$     865.585795  tC/GDP(PPP) M$       2.426659e+07
# 192452      tC/GDP M$     807.123792  tC/GDP(PPP) M$       2.337021e+07
# 192453      tC/GDP M$     784.476286  tC/GDP(PPP) M$       1.926484e+07
#
#        Unit_norm_gdp_hab Value_norm_ppp_hab Unit_norm_ppp_hab  \
# 0              tC/k$/hab       5.725083e+05    tC/k$(PPP)/hab
# 1              tC/k$/hab       6.332094e+05    tC/k$(PPP)/hab
# 2              tC/k$/hab       4.201025e+05    tC/k$(PPP)/hab
# 3              tC/k$/hab       3.404567e+05    tC/k$(PPP)/hab
# 4              tC/k$/hab       2.705050e+05    tC/k$(PPP)/hab
# ...                  ...                ...               ...
# 192449         tC/k$/hab       1.357967e+07    tC/k$(PPP)/hab
# 192450         tC/k$/hab       1.525736e+07    tC/k$(PPP)/hab
# 192451         tC/k$/hab       1.390915e+07    tC/k$(PPP)/hab
# 192452         tC/k$/hab       1.318907e+07    tC/k$(PPP)/hab
# 192453         tC/k$/hab       1.304927e+07    tC/k$(PPP)/hab
#
#         Value_norm_densite  Unit_norm_densite
# 0             1.267265e+04         tC/hab/km²
# 1             1.055924e+04         tC/hab/km²
# 2             6.731351e+03         tC/hab/km²
# 3             6.193447e+03         tC/hab/km²
# 4             5.510530e+03         tC/hab/km²
# ...                    ...                ...
# 192449        1.187786e+06         tC/hab/km²
# 192450        1.189931e+06         tC/hab/km²
# 192451        1.192086e+06         tC/hab/km²
# 192452        1.192853e+06         tC/hab/km²
# 192453                 NaN         tC/hab/km²
#
# [192454 rows x 36 columns]
